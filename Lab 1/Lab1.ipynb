# %%
from __future__ import division
from posixpath import split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# Excercise 1 function
def scale_data(data_array):
  stdev = np.std(data_array)
  output_array = []
  mean = np.mean(data_array)
  for i in range(len(data_array)):
    output_array.append((data_array[i] - mean)/stdev)
  return output_array


# Excercise 2 function
def split_data(arr, split_proportions, axis):
  output_array = ([])
  errcatch = 0

  # Normalize proportions
  for i in range(len(split_proportions)):
    errcatch += split_proportions[i]
  if(errcatch > 1):
    for i in range(len(split_proportions)):
      split_proportions[i] = split_proportions[i]/errcatch
  print(split_proportions)

  # Find division sizes
  division_sizes = []
  truesplit = 0
  for split in split_proportions:
    truesplit += int(np.shape(arr)[axis] * split)
    print(truesplit)
    division_sizes.append(truesplit)

  print(division_sizes)
  if(axis):
    print("hi")
    output_array = np.hsplit(arr, division_sizes)
  else:
    print("hi")
    output_array = np.vsplit(arr, division_sizes)
  return output_array
# Out:
# The kernel failed to start as the Python Environment 'phys548 (Python -1.-1.-1)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.

# %%
# Excercise 1 function test with x

hgcal = pd.read_csv('/media/hgcal.csv')

scaled_hgcal = []
scaled_hgcal = scale_data(hgcal['x'])

plt.hist(scaled_hgcal)
plt.show()

# %%
# Excercise 2 function test

hgcal = pd.read_csv('/media/hgcal.csv')

output = []

output = split_data(hgcal, [2, 2, 4], 1)
print(np.shape(output[0]))
# Out:
# [0.25, 0.25, 0.5]
# 2
# 4
# 8
# [2, 4, 8]
# hi
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_531/4279212120.py in <cell line: 0>()
#       5 output = []
#       6
# ----> 7 output = split_data(hgcal, [2, 2, 4], 1)
#       8 print(np.shape(output[0]))
#
# /tmp/ipykernel_531/2989701725.py in split_data(arr, split_proportions, axis)
#      40   if(axis):
#      41     print("hi")
# ---> 42     output_array = np.hsplit(arr, np.hstack(division_sizes))
#      43   else:
#      44     print("hi")
#
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_shape_base_impl.py in hsplit(ary, indices_or_sections)
# ...
